# %%
# HN CSV 乾淨版
# !pip install PyMuPDF

import fitz
import re
import csv


def extract_and_process_segments_with_page_number(pdf_file_path, csv_file_path):
    all_text = ""
    page_breaks = []

    with fitz.open(pdf_file_path) as doc:
        for page_num in range(len(doc)):
            page = doc.load_page(page_num)
            text = page.get_text()
            all_text += text
            page_breaks.append(len(all_text))

    all_text = re.sub(r'Page \d+ of \d+', '', all_text)

    page_content = []

    def process_section(regex, section_name):
        matches = re.finditer(regex, all_text, re.S)
        for match in matches:
            start_pos = match.start()
            page_number = next(pn for pn, pb in enumerate(page_breaks, start=1) if start_pos < pb)
            content = match.group(1).strip()
            page_content.append([page_number, section_name, content])

    process_section(r'Core Terms\s+([\s\S]+?)(?=\n(?:[A-Z][^\s]*(?:\s[A-Z][^\s]*)*[:\n]|Opinion by:))', "Core Terms")
    process_section(r'LexisNexis® Headnotes\s+(.+?)(?=HN\d+|$)', "Headnotes")

    hn_matches = re.findall(r'HN\d+\[.*?\].+?(?=HN\d+|LexisNexis® Headnotes|\Z)', all_text, re.DOTALL)
    for match in hn_matches:
        match_start = all_text.find(match)
        page_number = next(pn for pn, pb in enumerate(page_breaks, start=1) if match_start < pb)
        lines = match.split('\n')
        ongoing_hn_label = ""
        ongoing_hn_content = ""
        for line in lines:
            if 'HN' in line:
                if ongoing_hn_label and ongoing_hn_content:
                    page_content.append([page_number, ongoing_hn_label, ongoing_hn_content.strip()])
                ongoing_hn_label = line
                ongoing_hn_content = ""
            elif ">" in line:
                ongoing_hn_content += line.strip() + " "
        if ongoing_hn_label and ongoing_hn_content:
            page_content.append([page_number, ongoing_hn_label, ongoing_hn_content.strip()])

    core_terms_count = sum(1 for row in page_content if row[1] == "Core Terms")
    headnotes_count = sum(1 for row in page_content if row[1] == "Headnotes")
    hn1_count = sum(1 for row in page_content if row[1].startswith("HN1["))

    with open(csv_file_path, 'w', encoding='utf-8', newline='') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(['Page', 'Section', 'Content'])
        csv_writer.writerows(page_content)

    print(f'Core Terms 數量: {core_terms_count}')
    print(f'Headnotes 數量: {headnotes_count}')
    print(f'HN1[ 數量: {hn1_count}')

pdf_file_path = r'C:\Users\User\Dropbox\textmining1\PDF\Files (35).PDF'
csv_file_path = r'C:\Users\User\Dropbox\textmining1\HN\HN_35.csv'

extract_and_process_segments_with_page_number(pdf_file_path, csv_file_path)
# Out:
# Core Terms 數量: 35
# Headnotes 數量: 34
# HN1[ 數量: 35

# %%
# HN CSV (CoreTerms,Headnotes,HN) 註解版

# !pip install PyMuPDF
# !pip install --upgrade PyMuPDF

import fitz
import re
import csv


def extract_and_process_segments_with_page_number(pdf_file_path, csv_file_path):
    all_text = ""   #儲存PDF文本內容
    page_breaks = []  #儲存每個頁面的文本結尾位置

    with fitz.open(pdf_file_path) as doc: #打開PDF 作為doc處理 , with 表退出區塊後自動關閉PDF文件
        for page_num in range(len(doc)): #尋找所有頁面
            page = doc.load_page(page_num)  #載入當前頁面輸入Page變數
            text = page.get_text()    #獲取當前頁面文本
            all_text += text      #將文本附加到all_text變數中以供後續處理
            page_breaks.append(len(all_text)) #計算all_text長度,以計算頁數

    all_text = re.sub(r'Page \d+ of \d+', '', all_text) #去除Page of 頁碼

    page_content = []   #儲存處理後的文本,將每一行存為列表中的一個單位

    def process_section(regex, section_name): # regex(正則表達式),section_name(區段名稱) #處理文本並提取目標內容
        matches = re.finditer(regex, all_text, re.S) #re.S 匹配包含換行符的所有字元
        for match in matches:
            start_pos = match.start() #獲取匹配文本的起始位置
            page_number = next(pn for pn, pb in enumerate(page_breaks, start=1) if start_pos < pb) #透過比對'start_pos','page_breaks'的位置找到匹配文本頁數
            content = match.group(1).strip() #獲取文本內容,使用strip去除首尾空白字符
            page_content.append([page_number, section_name, content]) #將頁數,區段名稱,內容作為一個列表添加到page_content

    process_section(r'Core Terms\s+([\s\S]+?)(?=\n(?:[A-Z][^\s]*(?:\s[A-Z][^\s]*)*[:\n]|Opinion by:))', "Core Terms")
# '以Core Terms開頭' , '\s+ 匹配多個空格符,允許區段名稱前有多個空格', '([\s\S]+?) 使用括號將匹配內容捕獲到Group中,匹配任意字符,+? 表示非貪婪匹配,匹配最短內容'
# '(?=\n ...) 要求接下來的文本必須符合括號內條件,但不包含在匹配的結果中', '(?: ....) 非捕獲分組,用於組合多個匹配條件 '
# '[A-Z] 匹配大寫字母 ' , '[^\s]匹配0個或多個非空格的字符'  , '(?:\s[A-Z][^\s]*)* 匹配一個或多個以空格分隔的大寫字母單詞'
# '[:\n] 匹配冒號或換行符' , '|Opinion by: 表示或以 Opinion by:做為結束標記

    process_section(r'LexisNexis® Headnotes\s+(.+?)(?=HN\d+|$)', "Headnotes")
# '(.+?)匹配任何字符,用括號將匹配內容捕獲到分組中' , (?=HN\d+|$)使用正向查找來限制匹配的結尾,' HN\d+：匹配以"HN"開頭並後面跟著一個或多個數字的字串，這表示區段的結束標記 '
#'$：匹配文本的結尾，用於處理區段出現在文本結尾的情況'

    hn_matches = re.findall(r'HN\d+\[.*?\].+?(?=HN\d+|LexisNexis® Headnotes|\Z)', all_text, re.DOTALL) # 匹配類似"HN1[]"格式的區段
# ' HN\d+ 匹配以"HN"開頭並後面跟著一個或多個數字的字串，表示區段的開始標記' , '\[.*?\] 匹配方括號，用於包圍區段標籤 ' , '(?=HN\d+|\Z)：使用正向查找來限制匹配的結尾 '
# |LexisNexis® Headnotes| or ... or ...當結尾 , 加這個很重要, 解決Headnotes被誤認為HN的一部份
    for match in hn_matches: #尋找所有HN格式的區段
        match_start = all_text.find(match) #獲取匹配區段的起始位置

        page_number = next(pn for pn, pb in enumerate(page_breaks, start=1) if match_start < pb)
#比對'match_start'和'page_breaks'中的位置,找到匹配區段所在的頁數

        lines = match.split('\n') #將匹配區段按照換行符號分割成多行,逐行處理(解決換行後無法匹配的情況)
        ongoing_hn_label = "" #遇到包含">"的行,將行內容添加到ongoing_hn_content
        ongoing_hn_content = ""
        for line in lines:
            if 'HN' in line:
                if ongoing_hn_label and ongoing_hn_content: #若Label & content都包含內容,將他們及頁數添加到page_content列表
                    page_content.append([page_number, ongoing_hn_label, ongoing_hn_content.strip()])
                ongoing_hn_label = line
                ongoing_hn_content = ""
            elif ">" in line:
                ongoing_hn_content += line.strip() + " "
        if ongoing_hn_label and ongoing_hn_content:
            page_content.append([page_number, ongoing_hn_label, ongoing_hn_content.strip()])

    # 計算 Core Terms、Headnotes 和 HN1[ 的數量
    core_terms_count = sum(1 for row in page_content if row[1] == "Core Terms")
    headnotes_count = sum(1 for row in page_content if row[1] == "Headnotes")
    hn1_count = sum(1 for row in page_content if row[1].startswith("HN1["))

    with open(csv_file_path, 'w', encoding='utf-8', newline='') as csv_file: #寫入模式'w'編碼為UTF-8 且不添加額外空行
        csv_writer = csv.writer(csv_file) #將數據輸入CSV
        csv_writer.writerow(['Page', 'Section', 'Content']) #寫入標題
        csv_writer.writerows(page_content)   #寫入內容

    # 打印統計結果
    print(f'Core Terms 數量: {core_terms_count}')
    print(f'Headnotes 數量: {headnotes_count}')
    print(f'HN1[ 數量: {hn1_count}')

pdf_file_path = r'C:\Users\User\Dropbox\textmining\PDF\Files (100).PDF'
csv_file_path = r'C:\Users\User\Dropbox\textmining\HN\HN_100_.csv'

extract_and_process_segments_with_page_number(pdf_file_path, csv_file_path)
# Out:
# Core Terms 數量: 100
# Headnotes 數量: 95
# HN1[ 數量: 95

# %% [markdown]
# + 新發現：以Core Terms 和 End of Document 做為每一個判例的開頭和結尾
#
#     + 用這種方式去切割文本然後再抓取目標文本

# %%
import fitz  # PyMuPDF
import re
import csv

def extract_cases_and_process(pdf_file_path, csv_file_path):
    cases_text = []

    with fitz.open(pdf_file_path) as doc:
        full_text = ""
        for page_num in range(len(doc)):
            page_text = doc[page_num].get_text("text")
            full_text += page_text + "\n\n"

        case_splits = re.split(r'Core Terms|End of Document', full_text)
        cases_text = [case_splits[i] for i in range(1, len(case_splits), 2)]

    headnotes_counter = 0  # 初始化计数器

    for case_index, case_text in enumerate(cases_text, start=1):
        headnotes = re.findall(r'LexisNexis® Headnotes(.+?)(?=HN\d+|$)', case_text, re.DOTALL)
        
        # 计算并累加Headnotes的数量
        headnotes_counter += len(headnotes)
        
        # 打印或保存提取的信息
        print(f"Case {case_index}, Headnotes:", headnotes)

    # 打印LexisNexis® Headnotes总数量
    print(f"Total LexisNexis® Headnotes Count: {headnotes_counter}")

# 示例文件路径，需要替换为您的文件路径
pdf_file_path = r'C:\Users\User\Dropbox\textmining1\PDF\Files (100).PDF'
csv_file_path = r'C:\Users\User\Dropbox\textmining1\HN\test.csv'

extract_cases_and_process(pdf_file_path, csv_file_path)
# Out:
# Case 1, Headnotes: ['\nAntitrust & Trade Law > Sherman Act > General Overview\n']
# Case 2, Headnotes: ['\nAntitrust & Trade Law > Sherman Act > General Overview\n']
# Case 3, Headnotes: ['\nCommunications Law > ... > Licensing > Renewals & Revocations > General Overview\n']
# Case 4, Headnotes: ['\nBusiness & Corporate Compliance > ... > Transportation Law > Interstate Commerce > Restraints of Trade\n']
# Case 5, Headnotes: ['\nAntitrust & Trade Law > Sherman Act > General Overview\n']
# Case 6, Headnotes: ['\nAntitrust & Trade Law > Sherman Act > General Overview\nCriminal Law & Procedure > Sentencing > Fines\n']
# Case 7, Headnotes: ['\nAntitrust & Trade Law > Public Enforcement > State Civil Actions\nBusiness & Corporate Compliance > ... > Labor & Employment Law > Collective Bargaining & Labor \nRelations > Bargaining Subjects\n']
# Case 8, Headnotes: ['\nCivil Procedure > ... > Jurisdiction on Certiorari > Considerations Governing Review > Federal Court Decisions\n']
# Case 9, Headnotes: ['\nAntitrust & Trade Law > Clayton Act > General Overview\n']
# Case 10, Headnotes: ['\nAntitrust & Trade Law > Sherman Act > General Overview\nAntitrust & Trade Law > ... > Price Fixing & Restraints of Trade > Tying Arrangements > General Overview\nAntitrust & Trade Law > ... > Price Fixing & Restraints of Trade > Tying Arrangements > Sherman Act Violations\n']
# Case 11, Headnotes: ['\nCivil Procedure > ... > Summary Judgment > Hearings > General Overview\nCivil Procedure > ... > Summary Judgment > Entitlement as Matter of Law > General Overview\nCivil Procedure > ... > Summary Judgment > Entitlement as Matter of Law > Genuine Disputes\nCivil Procedure > ... > Summary Judgment > Entitlement as Matter of Law > Materiality of Facts\n']
# Case 12, Headnotes: ['\nAntitrust & Trade Law > Sherman Act > General Overview\n']
# Case 13, Headnotes: ['\nAntitrust & Trade Law > Sherman Act > General Overview\n']
# Case 14, Headnotes: ['\nAntitrust & Trade Law > Clayton Act > General Overview\n']
# Case 15, Headnotes: ['\nAntitrust & Trade Law > Clayton Act > Penalties\nCriminal Law & Procedure > Appeals > Right to Appeal > Government\nAntitrust & Trade Law > Clayton Act > General Overview\n']
# Case 16, Headnotes: []
# Case 17, Headnotes: ['\nAntitrust & Trade Law > Clayton Act > General Overview\nGovernments > Legislation > Statute of Limitations > Time Limitations\n']
# Case 18, Headnotes: ['\nAntitrust & Trade Law > Robinson-Patman Act > Claims\nAntitrust & Trade Law > Robinson-Patman Act > General Overview\n']
# Case 19, Headnotes: ['\nAntitrust & Trade Law > Sherman Act > General Overview\n']
# Case 20, Headnotes: ['\nAntitrust & Trade Law > Clayton Act > General Overview\n']
# Case 21, Headnotes: ['\nAntitrust & Trade Law > Public Enforcement > US Federal Trade Commission Actions > General Overview\nBanking Law > Federal Acts > Federal Trade Commission Act > Unfair Competition & Practices\nAntitrust & Trade Law > Federal Trade Commission Act > General Overview\nAntitrust & Trade Law > ... > US Federal Trade Commission Actions > Remedial Powers > General Overview\n']
# Case 22, Headnotes: ['\nCivil Procedure > Remedies > Writs > All Writs Act\nCivil Procedure > ... > Subject Matter Jurisdiction > Jurisdiction Over Actions > General Overview\nCivil Procedure > Remedies > Writs > General Overview\nCivil Procedure > Appeals > Appellate Jurisdiction > General Overview\n']
# Case 23, Headnotes: ['\nSecurities Law > ... > Registration of Securities > Exemptions > Exempt Classes of Securities\nTransportation Law > Interstate Commerce > Federal Powers\n']
# Case 24, Headnotes: []
# Case 25, Headnotes: ['\nAntitrust & Trade Law > Regulated Industries > Financial Institutions > General Overview\n']
# Case 26, Headnotes: ['\nAntitrust & Trade Law > ... > Private Actions > Remedies > General Overview\nCivil Procedure > ... > Defenses, Demurrers & Objections > Affirmative Defenses > General Overview\n']
# Case 27, Headnotes: ['\nAntitrust & Trade Law > Clayton Act > Penalties\nAntitrust & Trade Law > Clayton Act > General Overview\n']
# Case 28, Headnotes: ['\nCivil Procedure > Judgments > Entry of Judgments > Nonparties Affected by Judgment\n']
# Case 29, Headnotes: ['\nCivil Procedure > ... > Defenses, Demurrers & Objections > Affirmative Defenses > Releases\nGovernments > Legislation > Statute of Limitations > Pleadings & Proof\nCivil Procedure > ... > Defenses, Demurrers & Objections > Affirmative Defenses > General Overview\nGovernments > Legislation > Statute of Limitations > General Overview\n']
# Case 30, Headnotes: ['\nAntitrust & Trade Law > Federal Trade Commission Act > General Overview\nBanking Law > Federal Acts > Federal Trade Commission Act > Unfair Competition & Practices\n']
# Case 31, Headnotes: ['\nAntitrust & Trade Law > Sherman Act > General Overview\n']
# Case 32, Headnotes: ['\nAntitrust & Trade Law > Regulated Industries > Sports > Baseball\nGovernments > Courts > Judicial Precedent\nInternational Trade Law > General Overview\nAntitrust & Trade Law > Regulated Industries > Sports > General Overview\n']
# Case 33, Headnotes: ['\nGovernments > Legislation > Interpretation\n']
# Case 34, Headnotes: ['\nAntitrust & Trade Law > Sherman Act > Remedies > Injunctions\nCivil Procedure > ... > Injunctions > Grounds for Injunctions > Public Interest\nPatent Law > Remedies > Equitable Relief > Injunctions\nAntitrust & Trade Law > ... > Intellectual Property > Ownership & Transfer of Rights > Licenses\nCivil Procedure > ... > Justiciability > Standing > General Overview\nBusiness & Corporate Compliance > ... > Defenses > Inequitable Conduct > Anticompetitive Conduct\nPatent Law > ... > Defenses > Patent Invalidity > General Overview\nBusiness & Corporate Compliance > ... > Ownership > Conveyances > Licenses\n']
# Case 35, Headnotes: ['\nMergers & Acquisitions Law > Antitrust > Antitrust Statutes > Clayton Act\n']
# Case 36, Headnotes: []
# Case 37, Headnotes: ['\nAntitrust & Trade Law > Robinson-Patman Act > General Overview\n']
# Case 38, Headnotes: ['\nAntitrust & Trade Law > Exemptions & Immunities >
Headnotes: ['\nAntitrust & Trade Law > Clayton Act > Remedies > Damages\nAntitrust & Trade Law > Clayton Act > General Overview\nAntitrust & Trade Law > Clayton Act > Remedies > General Overview\nAntitrust & Trade Law > ... > Price Fixing & Restraints of Trade > Vertical Restraints > Price Fixing\nAntitrust & Trade Law > Regulated Practices > Private Actions > Prioritizing Resources & Organization for \nIntellectual Property Act\nAntitrust & Trade Law > Sherman Act > Scope > General Overview\nAntitrust & Trade Law > ... > US Department of Justice Actions > Civil Actions > General Overview\n']
# Case 91, Headnotes: ['\nAntitrust & Trade Law > ... > Price Discrimination > Defenses > Meeting Competition Defense\nContracts Law > Personal Property > Bona Fide Purchasers\nAntitrust & Trade Law > Regulated Practices > Price Discrimination > Promotional Allowances & Services\nAntitrust & Trade Law > Robinson-Patman Act > General Overview\n']
# Case 92, Headnotes: ['\nAntitrust & Trade Law > Clayton Act > General Overview\n']
# Case 93, Headnotes: ['\nBusiness & Corporate Compliance > ... > Transportation Law > Interstate Commerce > Restraints of Trade\nMergers & Acquisitions Law > Antitrust > Regulated Industry Mergers\nAntitrust & Trade Law > Regulated Industries > Transportation > General Overview\nMergers & Acquisitions Law > General Overview\nMergers & Acquisitions Law > Antitrust > General Overview\nTransportation Law > Interstate Commerce > General Overview\n* Together with No. 89-1028, CSX Transportation, Inc. v. Brotherhood of Railway Carmen et al., also on certiorari to the same \ncourt.\n\n\nPage 2 of 21\n \nBusiness & Corporate Compliance > ... > Transportation Law > Interstate Commerce > US Interstate \nCommerce Commission\n']
# Case 94, Headnotes: ['\nAntitrust & Trade Law > Exemptions & Immunities > Parker State Action Doctrine > General Overview\nBusiness & Corporate Compliance > ... > Governments > Agriculture & Food > Product Promotions\nAntitrust & Trade Law > Sherman Act > General Overview\n']
# Case 95, Headnotes: ['\nAntitrust & Trade Law > Sherman Act > General Overview\n']
# Case 96, Headnotes: ['\nAntitrust & Trade Law > ... > Price Fixing & Restraints of Trade > Tying Arrangements > General Overview\n']
# Case 97, Headnotes: ['\nAntitrust & Trade Law > Exemptions & Immunities > Parker State Action Doctrine > General Overview\nAntitrust & Trade Law > Exemptions & Immunities > General Overview\n']
# Case 98, Headnotes: ['\nAntitrust & Trade Law > ... > Intellectual Property > Bad Faith, Fraud & Nonuse > Fraud\nBusiness & Corporate Compliance > ... > Defenses > Inequitable Conduct > Anticompetitive Conduct\nAntitrust & Trade Law > Regulated Practices > Intellectual Property > General Overview\nAntitrust & Trade Law > ... > Intellectual Property > Bad Faith, Fraud & Nonuse > General Overview\nAntitrust & Trade Law > Regulated Practices > Market Definition > Relevant Market\nAntitrust & Trade Law > ... > Monopolies & Monopolization > Actual Monopolization > Claims\nAntitrust & Trade Law > ... > Monopolies & Monopolization > Attempts to Monopolize > General Overview\nPatent Law > ... > Defenses > Inequitable Conduct > General Overview\nPatent Law > ... > Defenses > Inequitable Conduct > Burdens of Proof\n']
# Case 99, Headnotes: ['\nAntitrust & Trade Law > Exemptions & Immunities > Noerr-Pennington Doctrine > General Overview\nAntitrust & Trade Law > Regulated Industries > General Overview\nAntitrust & Trade Law > Regulated Industries > Transportation > General Overview\n']
# Case 100, Headnotes: ['\nAntitrust & Trade Law > ... > Price Discrimination > Competitive Injuries > General Overview\nAntitrust & Trade Law > Robinson-Patman Act > General Overview\n']
# Total LexisNexis® Headnotes Count: 95
